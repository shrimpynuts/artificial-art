# %%
import argparse
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from skimage.transform import rescale, resize, downscale_local_mean
import pickle
import os

# %%
indir="../landscape"
outdir="../processed"
x = io.imread_collection(indir + "/*.jpg")

# %%
shapes = []
for img_file in x.files:
    a = io.imread(img_file)
    if (a.shape[0] == 100 or a.shape[1] == 100) or (len(a.shape) !=3):
        print(img_file)
        new_file = "./removed/" + img_file.split('/')[-1]
        print(new_file)
        os.rename(img_file, new_file)
    else:
        shapes.append(a.shape)

# %%
widths = [x[1] for x in shapes]

# %%
heights = [x[0] for x in shapes]

# %%
plt.figure(figsize=(20,20)) 
plt.plot(widths, heights, 'o')

# %%
stats.describe(np.asarray(widths))
# Out:
# DescribeResult(nobs=2332, minmax=(100, 8559), mean=1314.118782161235, variance=844832.1038598634, skewness=2.412637971472024, kurtosis=7.369008414851441)

# %%
stats.describe(np.asarray(heights))
# Out:
# DescribeResult(nobs=2332, minmax=(100, 5304), mean=1042.3636363636363, variance=592549.3374673375, skewness=2.0368255111155147, kurtosis=4.230764669450717)

# %%
x.files[0]
# Out:
# '../landscape/1.jpg'

# %%
ex1 = io.imread("../landscape/scene-on-a-river-1.jpg")
ex1_resized = resize(ex1, (256, 256), anti_aliasing=True)

# %%
def plot_resized(image, image_resized):
    fig, axes = plt.subplots(nrows=1, ncols=2,  figsize=(10,8))
    ax = axes.ravel()

    ax[0].imshow(image, cmap='gray')
    ax[0].set_title("Original image")

    ax[1].imshow(image_resized, cmap='gray')
    ax[1].set_title("Resized image (no aliasing)")
    plt.show()

# %%
plot_resized(ex1, ex1_resized)
print(ex1.shape)
# Out:
# (801, 1116, 3)

# %%
ex2 = io.imread("../landscape/the-monk-by-the-sea-0a.jpg")
ex2_resized = resize(ex2, (256, 256), anti_aliasing=True)

# %%
plot_resized(ex2, ex2_resized)
print(ex2.shape)
# Out:
# (750, 1174, 3)

# %%
ex3 = io.imread("../landscape/shoreham-bay-near-brighton-1824.jpg")
ex3_resized = resize(ex3, (500, 500), anti_aliasing=True)
plot_resized(ex3, ex3_resized)
print(ex3.shape)
# Out:
# (4747, 4200, 3)

# %%
ex3_resized.shape
# Out:
# (500, 500, 3)

# %%
ex3_resized.size
# Out:
# 750000

# %%
ex3.size
# Out:
# 59812200

# %%
ex3.shape
# Out:
# (4747, 4200, 3)

# %%
def scale_image(img, new_width, new_height):
    return resize(img, (new_width, new_height), anti_aliasing=True)

# %%
resized_np = []
for img_file in x.files:
    a = io.imread(img_file)
    if (len(a.shape) == 3): # filter out gray-scale images
        a_resized = scale_image(a, 500, 500)
        resized_np.append(a_resized)
        out_file = outdir + "/" + img_file.split("/")[2]
        io.imsave(out_file, a_resized)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
resized_pickle_file = open("./resized_data", 'wb')
pickle.dump(resized_np, resized_pickle_file)
